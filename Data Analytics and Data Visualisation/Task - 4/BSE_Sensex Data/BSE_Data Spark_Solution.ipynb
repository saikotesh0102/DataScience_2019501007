# %%
import pandas as pd
import os
import numpy as np
from itertools import combinations
from matplotlib import pyplot as plt

# %% [markdown]
# # Identify the top 10 gainers (%) across groups over the last 5 years period.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file, thousands = ",")
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by = "Date", inplace = True)
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(), columns = ["security", "gain"])
df.sort_values(by = "gain", inplace = True, ascending = False)
df.head(10)
# Out:
#    security      gain
# 63   500126  7.770662
# 59   500120  6.584091
# 26   500052  4.462151
# 55   500114  3.437920
# 11   500027  3.026806
# 36   500085  2.841322
# 5    500012  2.380471
# 99   500199  2.367250
# 23   500043  2.128142
# 31   500069  2.027523

# %% [markdown]
# # Identify the top 10 gainers (%) across groups over the last 3 years period.¶

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file, thousands = ",")
            df = df[0 : 750]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by = "Date", inplace = True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(), columns = ["security", "gain"])
df.sort_values(by = "gain", inplace = True, ascending = False)
df.head(10)
# Out:
#    security      gain
# 63   500126  4.623187
# 59   500120  2.417307
# 67   500136  2.264256
# 17   500034  2.037351
# 11   500027  1.467680
# 65   500133  1.333519
# 61   500124  1.155175
# 23   500043  1.153474
# 3    500009  0.936893
# 55   500114  0.793153

# %% [markdown]
# # Identify the top 10 gainers (%) across groups over the last 2 years period.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file, thousands = ",")
            df = df[0 : 500]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by = "Date", inplace = True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(), columns = ["security", "gain"])
df.sort_values(by = "gain",inplace = True, ascending = False)
df.head(10)
# Out:
#    security      gain
# 67   500136  2.180217
# 59   500120  1.542476
# 66   500135  1.481268
# 63   500126  1.344147
# 65   500133  1.090813
# 17   500034  1.076166
# 33   500078  1.044979
# 61   500124  0.975155
# 11   500027  0.888631
# 55   500114  0.746668

# %% [markdown]
# # Identify the top 10 gainers (%) across groups over the last 1 year period.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file, thousands = ",")
            df = df[0 : 250]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by = "Date", inplace = True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(), columns = ["security", "gain"])
df.sort_values(by = "gain", inplace = True, ascending = False)
df.head(10)
# Out:
#    security      gain
# 41   500093  3.058615
# 67   500136  2.277933
# 45   500102  2.255814
# 76   500160  1.960000
# 33   500078  1.928233
# 26   500052  1.613918
# 99   500199  1.607572
# 59   500120  1.597898
# 93   500187  1.321816
# 6    500013  1.156436

# %% [markdown]
# # Identify the top 10 gainers (%) across groups over the last 6 months period.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file, thousands = ",")
            df = df[0 : 130]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by = "Date", inplace = True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(), columns = ["security", "gain"])
df.sort_values(by = "gain", inplace = True, ascending = False)
df.head(10)
# Out:
#    security      gain
# 41   500093  4.519324
# 76   500160  4.481481
# 33   500078  2.233382
# 26   500052  2.084364
# 99   500199  1.959134
# 82   500170  1.543636
# 5    500012  1.425121
# 67   500136  1.394898
# 54   500113  1.353041
# 6    500013  1.254658

# %% [markdown]
# # Identify the top 10 gainers (%) across groups over the last 3 months period.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file, thousands = ",")
            df = df[0 : 75]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by = "Date", inplace = True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(), columns = ["security", "gain"])
df.sort_values(by = "gain", inplace = True, ascending = False)
df.head(10)
# Out:
#    security      gain
# 76   500160  2.920530
# 6    500013  1.503448
# 73   500151  1.253304
# 26   500052  1.155660
# 41   500093  0.888430
# 93   500187  0.765766
# 54   500113  0.763291
# 99   500199  0.677956
# 27   500055  0.668067
# 33   500078  0.633284

# %% [markdown]
# # Identify the top 10 gainers (%) across groups over the last 1 month period.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file, thousands = ",")
            df = df[0 : 30]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by = "Date", inplace = True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

# %%
df = pd.DataFrame(data.items(), columns = ["security", "gain"])
df.sort_values(by = "gain", inplace = True, ascending = False)
df.head(10)
# Out:
#    security      gain
# 68   500143  1.525263
# 6    500013  1.491991
# 73   500151  1.298876
# 7    500014  0.902174
# 82   500170  0.840789
# 76   500160  0.804878
# 91   500185  0.740883
# 54   500113  0.728288
# 24   500048  0.557455
# 5    500012  0.521212

# %% [markdown]
# # Identify the stock most correlated with ICICI Bank's stockprice

# %%
icici_bank = "532174"
df_icici_bank = pd.read_csv(icici_bank + ".csv",thousands = ",")

stock_corr = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            if name == icici_bank:
                continue
            df = pd.read_csv(file, thousands = ",")
            cor = df_icici_bank["Total Turnover (Rs.)"].corr(df["Total Turnover (Rs.)"])
            stock_corr[name] = cor

icici_corr = pd.DataFrame(stock_corr.items(),columns = ["security", "correlation"])
icici_corr = icici_corr.sort_values(by = "correlation", ascending = False)
icici_corr.head()
# Out:
#    security  correlation
# 53   500112     0.090095
# 25   500049     0.089473
# 4    500010     0.088603
# 93   500187     0.083852
# 87   500180     0.082222

# %% [markdown]
# # Draw a correlation matrix of any 30 stocks on the Sensex. This is a matrix with both axes holding the stock names. The colour of each cell is the correlation between that pair of stocks: blue for -1 and green for 1.

# %%
dfs = {}
stock_names = set()
def read_dfs():
    for root,dirs,files in os.walk(os.curdir):
        for file in files:
            if len(stock_names) == 30:
                return
            if file.endswith('.csv') and file.startswith("5"):
                name = os.path.splitext(file)[0]
                df = pd.read_csv(file, thousands = ",")
                dfs[name] = df
                stock_names.add(name)
read_dfs()

# %%
samp = pd.DataFrame(columns=stock_names,index=stock_names)
for n1,n2 in combinations(stock_names,2):
    df1 = dfs[n1]
    df2 = dfs[n2]
    c1 = df1["Total Turnover (Rs.)"].corr(df2["Total Turnover (Rs.)"])
    c2 = df2["Total Turnover (Rs.)"].corr(df1["Total Turnover (Rs.)"])
    samp.loc[n1,n2] = c1
    samp.loc[n2,n1] = c2
    samp.loc[n1,n1] = 1
    samp.loc[n2,n2] = 1
samp = samp.astype({name:"float" for name in stock_names})

# %%
samp.style.background_gradient(cmap="brg")
# Out:
# <style  type="text/css" >
# #T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row0_col0,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row1_col1,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row2_col2,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row3_col3,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row4_col4,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row5_col5,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row6_col6,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row7_col7,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row8_col8,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row9_col9,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row10_col10,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row11_col11,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row12_col12,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row13_col13,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row14_col14,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row15_col15,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row16_col16,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row17_col17,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row18_col18,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row19_col19,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row20_col20,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row21_col21,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row22_col22,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row23_col23,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row24_col24,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row25_col25,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row26_col26,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row27_col27,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row28_col28,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row29_col29{
#             background-color:  #00ff00;
#             color:  #000000;
#         }#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row0_col1,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row3_col24,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row5_col28,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row12_col2,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row12_col20,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row13_col5,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row14_col3,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row14_col5,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row16_col20,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row18_col6,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row24_col3,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row24_col25,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row26_col2,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row27_col16{
#             background-color:  #5000af;
#             color:  #f1f1f1;
#         }#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row0_col2,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row0_col5,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row0_col9,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row0_col20,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row4_col9,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row5_col1,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row6_col23,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row7_col24,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row8_col9,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row10_col9,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row12_col21,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row14_col6,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row19_col12,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row22_col6,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row22_col21,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row22_col25,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row22_col26,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row25_col10,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row26_col13,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row27_col21,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row28_col25{
#             background-color:  #2400db;
#             color:  #f1f1f1;
#         }#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row0_col3,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row2_col0,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row2_col22,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row3_col13,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row3_col21,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row6_col4,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row6_col22,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row7_col1,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row7_col4,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row7_col13,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row9_col18,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row9_col23,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row10_col4,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row10_col7,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row10_col13,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row12_col13,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row12_col15,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row14_col22,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row15_col22,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row15_col23,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row16_col11,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row16_col15,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row19_col11,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row19_col27,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row20_col22,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row21_col13,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row22_col4,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row26_col1,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row26_col16,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row26_col21,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row28_col22,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row29_col16{
#             background-color:  #1400eb;
#             color:  #f1f1f1;
#         }#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row0_col4,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row0_col27,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row4_col28,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row4_col29,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row6_col20,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row7_col14,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row9_col28,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row12_col8,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row14_col11,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row20_col24,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row22_col8,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row23_col3,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row27_col1{
#             background-color:  #3e00c1;
#             color:  #f1f1f1;
#         }#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row0_col6,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row5_col26,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row10_col2,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row10_col14,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row10_col29,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row11_col28,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row13_col14,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row13_col18,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row15_col2,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row16_col28,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row20_col28,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row26_col5{
#             background-color:  #4a00b5;
#             color:  #f1f1f1;
#         }#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row0_col7,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row0_col13,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row1_col26,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row2_col9,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row3_col15,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row5_col11,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row5_col21,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row7_col21,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row10_col0,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row10_col26,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row11_col22,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row13_col6,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row15_col9,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row17_col9,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row18_col2,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row18_col13,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row19_col9,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row21_col0,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row21_col5,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row28_col10{
#             background-color:  #2600d9;
#             color:  #f1f1f1;
#         }#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row0_col8,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row4_col3,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row9_col8,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row10_col8,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0d2row10_col25,#T_c4f22870_712b_11eb_958f_d0bf9c8fa0

# %% [markdown]
# # Draw a sparkline showing the data 23,80,92,62,98,7,9,56,19,68.

# %%
import base64
import io


def spark_line(data, figsize = (4, 0.25), **kwags):
    """
    Returns a HTML image tag containing a base64 encoded sparkline style plot
    """
    data = list(data)

    fig, ax = plt.subplots(1, 1, figsize = figsize, **kwags)
    ax.plot(data)
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_xticks([])
    ax.set_yticks([])

    plt.plot(len(data) - 1, data[len(data) - 1], 'r.')

    ax.fill_between(range(len(data)), data, len(data) * [min(data)], alpha = 0.1)

    img = io.BytesIO()
    plt.savefig(img, transparent=True, bbox_inches = 'tight')
    img.seek(0)
    plt.close()

    return base64.b64encode(img.read()).decode("UTF-8")

# %%
values = [23,80,92,62,98,7,9,56,19,68]

with open("sparkline2.html", "a") as file:
        file.write('<div><h1>Sparkline to the given values</h1></div>')
        file.write('<br>')
        file.write('<br>')
        file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(values)))
        file.write('<div></div>')

# %% [markdown]
# # For each stock, draw a sparkline showing last month's closing price trend

# %%
closing_price_values = list()
for file in os.listdir():
    if file.endswith('.csv') and file.startswith("5"):
        filename = os.path.splitext(file)[0]
        if not filename.isdecimal() :
            continue
        df = pd.read_csv(file, thousands = ",")
        try:
            closing_price_values.append(df["Close"][0 : 30].values)
        except Exception as e:
            closing_price_values.append(df["Close Price"][0 : 30].values)

with open("bse_closing_price3.html", "a") as file:
    file.write('<div><h1>Sparkline to the Closing Price values</h1></div>')
    file.write('<br>')
    file.write('<br>')
    for value in closing_price_values:
        file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(value)))
        file.write('<div></div>')
