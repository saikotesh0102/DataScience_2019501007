# %%
import pandas as pd 
import numpy as np

# %%
name = pd.read_csv('D:/Study/MSIT/2nd Year/DataScience_2019501007/Data Analytics and Data Visualisation/Task - 1/IMDB Data/name_basics.tsv', sep = "\t", header = 0)
basics = pd.read_csv('D:/Study/MSIT/2nd Year/DataScience_2019501007/Data Analytics and Data Visualisation/Task - 1/IMDB Data/title_basics.tsv', sep = "\t", header = 0)
ratings = pd.read_csv('D:/Study/MSIT/2nd Year/DataScience_2019501007/Data Analytics and Data Visualisation/Task - 1/IMDB Data/title_ratings.tsv', sep = "\t", header = 0)
# akas = pd.read_csv('D:/Study/MSIT/2nd Year/DataScience_2019501007/Data Analytics and Data Visualisation/Task - 1/IMDB Data/title_akas.tsv', sep = "\t", header = 0)
# crew = pd.read_csv('D:/Study/MSIT/2nd Year/DataScience_2019501007/Data Analytics and Data Visualisation/Task - 1/IMDB Data/title_crew.tsv', sep = "\t", header = 0)
# episode = pd.read_csv('D:/Study/MSIT/2nd Year/DataScience_2019501007/Data Analytics and Data Visualisation/Task - 1/IMDB Data/title_episode.tsv', sep = "\t", header = 0)
# principals = pd.read_csv('D:/Study/MSIT/2nd Year/DataScience_2019501007/Data Analytics and Data Visualisation/Task - 1/IMDB Data/title_principals.tsv', sep = "\t", header = 0)
# Out:
# C:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
temp_basics = basics[basics["startYear"] != "\\N"]
temp_basics = temp_basics.astype({"startYear":"int"})
print(temp_basics.dtypes)
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           object
# startYear          int32
# endYear           object
# runtimeMinutes    object
# genres            object
# dtype: object

# %%
sol = pd.merge(temp_basics, ratings, on = "tconst")
print(sol.head())
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult  startYear endYear runtimeMinutes                    genres  \
# 0       0       1894      \N              1         Documentary,Short
# 1       0       1892      \N              5           Animation,Short
# 2       0       1892      \N              4  Animation,Comedy,Romance
# 3       0       1892      \N             12           Animation,Short
# 4       0       1893      \N              1              Comedy,Short
#
#    averageRating  numVotes
# 0            5.7      1669
# 1            6.1       207
# 2            6.5      1392
# 3            6.2       123
# 4            6.2      2181

# %% [markdown]
# # To Find the 20 most popular movies with a rank more than 8.0

# %%
temp_result = sol[(sol['averageRating'] > 8.0) & (sol["titleType"] == 'movie')]
result = temp_result.sort_values(by = 'numVotes', ascending = False)
result.head(20)
# Out:
#            tconst titleType  \
# 81773   tt0111161     movie
# 246038  tt0468569     movie
# 582013  tt1375666     movie
# 98054   tt0137523     movie
# 81557   tt0110912     movie
# 80684   tt0109830     movie
# 95969   tt0133093     movie
# 89544   tt0120737     movie
# 112866  tt0167260     movie
# 45695   tt0068646     movie
# 574443  tt1345836     movie
# 387558  tt0816692     movie
# 112867  tt0167261     movie
# 84325   tt0114369     movie
# 666609  tt1853728     movie
# 115287  tt0172495     movie
# 206365  tt0372784     movie
# 74992   tt0102926     movie
# 201320  tt0361748     movie
# 89606   tt0120815     movie
#
#                                              primaryTitle  \
# 81773                            The Shawshank Redemption
# 246038                                    The Dark Knight
# 582013                                          Inception
# 98054                                          Fight Club
# 81557                                        Pulp Fiction
# 80684                                        Forrest Gump
# 95969                                          The Matrix
# 89544   The Lord of the Rings: The Fellowship of the Ring
# 112866      The Lord of the Rings: The Return of the King
# 45695                                       The Godfather
# 574443                              The Dark Knight Rises
# 387558                                       Interstellar
# 112867              The Lord of the Rings: The Two Towers
# 84325                                               Se7en
# 666609                                   Django Unchained
# 115287                                          Gladiator
# 206365                                      Batman Begins
# 74992                            The Silence of the Lambs
# 201320                               Inglourious Basterds
# 89606                                 Saving Private Ryan
#
#                                             originalTitle isAdult  startYear  \
# 81773                            The Shawshank Redemption       0       1994
# 246038                                    The Dark Knight       0       2008
# 582013                                          Inception       0       2010
# 98054                                          Fight Club       0       1999
# 81557                                        Pulp Fiction       0       1994
# 80684                                        Forrest Gump       0       1994
# 95969                                          The Matrix       0       1999
# 89544   The Lord of the Rings: The Fellowship of the Ring       0       2001
# 112866      The Lord of the Rings: The Return of the King       0       2003
# 45695                                       The Godfather       0       1972
# 574443                              The Dark Knight Rises       0       2012
# 387558                                       Interstellar       0       2014
# 112867              The Lord of the Rings: The Two Towers       0       2002
# 84325                                               Se7en       0       1995
# 666609                                   Django Unchained       0       2012
# 115287                                          Gladiator       0       2000
# 206365                                      Batman Begins       0       2005
# 74992                            The Silence of the Lambs       0       1991
# 201320                               Inglourious Basterds       0       2009
# 89606                                 Saving Private Ryan       0       1998
#
#        endYear runtimeMinutes                   genres  averageRating  \
# 81773       \N            142                    Drama            9.3
# 246038      \N            152       Action,Crime,Drama            9.0
# 582013      \N            148  Action,Adventure,Sci-Fi            8.8
# 98054       \N            139                    Drama            8.8
# 81557       \N            154              Crime,Drama            8.9
# 80684       \N            142            Drama,Romance            8.8
# 95969       \N            136            Action,Sci-Fi            8.7
# 89544       \N            178   Action,Adventure,Drama            8.8
# 112866      \N            201   Action,Adventure,Drama            8.9
# 45695       \N            175              Crime,Drama            9.2
# 574443      \N            164         Action,Adventure            8.4
# 387558      \N            169   Adventure,Drama,Sci-Fi            8.6
# 112867      \N            179   Action,Adventure,Drama            8.7
# 84325       \N            127      Crime,Drama,Mystery            8.6
# 666609      \N            165            Drama,Western            8.4
# 115287      \N            155   Action,Adventure,Drama            8.5
# 206365      \N            140         Action,Adventure            8.2
# 74992       \N            118     Crime,Drama,Thriller            8.6
# 201320      \N            153      Adventure,Drama,War            8.3
# 89606       \N            169                Drama,War            8.6
#
#         numVotes
# 81773    2326344
# 246038   2288140
# 582013   2051750
# 98054    1842531
# 81557    1814425
# 80684    1795075
# 95969    1664961
# 89544    1649550
# 112866   1632805
# 45695    1607349
# 574443   1507477
# 387558   1496586
# 112867   1476251
# 84325    1434119
# 666609   1347347
# 115287   1333117
# 206365   1300916
# 74992    1261810
# 201320   1257816
# 89606    1227548

# %% [markdown]
# # To find the 20 best rated movies with over 40,000 votes in the 2000s (year >= 2000)

# %%
rated_movies = sol[(sol["numVotes"] >= 40000) & (sol["startYear"] >= 2000) & (sol["titleType"] == 'movie')]
res = rated_movies.sort_values(by = 'averageRating', ascending = False)
res.head(20)
# Out:
#              tconst titleType  \
# 752672    tt2592910     movie
# 246038    tt0468569     movie
# 112866    tt0167260     movie
# 582013    tt1375666     movie
# 940296    tt5813916     movie
# 89544     tt0120737     movie
# 445593   tt10189514     movie
# 112867    tt0167261     movie
# 990094    tt6751668     movie
# 183922    tt0317248     movie
# 149309    tt0245429     movie
# 1063691   tt8503618     movie
# 387558    tt0816692     movie
# 636259    tt1675434     movie
# 152941    tt0253474     movie
# 115287    tt0172495     movie
# 752115    tt2582802     movie
# 251928    tt0482571     movie
# 590882    tt1424432     movie
# 221907    tt0407887     movie
#
#                                               primaryTitle  \
# 752672                              CM101MMXI Fundamentals
# 246038                                     The Dark Knight
# 112866       The Lord of the Rings: The Return of the King
# 582013                                           Inception
# 940296                                     The Mountain II
# 89544    The Lord of the Rings: The Fellowship of the Ring
# 445593                                     Soorarai Pottru
# 112867               The Lord of the Rings: The Two Towers
# 990094                                            Parasite
# 183922                                         City of God
# 149309                                       Spirited Away
# 1063691                                           Hamilton
# 387558                                        Interstellar
# 636259                                    The Intouchables
# 152941                                         The Pianist
# 115287                                           Gladiator
# 752115                                            Whiplash
# 251928                                        The Prestige
# 590882                                               Senna
# 221907                                        The Departed
#
#                                              originalTitle isAdult  startYear  \
# 752672                              CM101MMXI Fundamentals       0       2013
# 246038                                     The Dark Knight       0       2008
# 112866       The Lord of the Rings: The Return of the King       0       2003
# 582013                                           Inception       0       2010
# 940296                                              Dag II       0       2016
# 89544    The Lord of the Rings: The Fellowship of the Ring       0       2001
# 445593                                     Soorarai Pottru       0       2020
# 112867               The Lord of the Rings: The Two Towers       0       2002
# 990094                                        Gisaengchung       0       2019
# 183922                                      Cidade de Deus       0       2002
# 149309                       Sen to Chihiro no kamikakushi       0       2001
# 1063691                                           Hamilton       0       2020
# 387558                                        Interstellar       0       2014
# 636259                                        Intouchables       0       2011
# 152941                                         The Pianist       0       2002
# 115287                                           Gladiator       0       2000
# 752115                                            Whiplash       0       2014
# 251928                                        The Prestige       0       2006
# 590882                                               Senna       0       2010
# 221907                                        The Departed       0       2006
#
#         endYear runtimeMinutes                       genres  averageRating  \
# 752672       \N            139           Comedy,Documentary            9.2
# 246038       \N            152           Action,Crime,Drama            9.0
# 112866       \N            201       Action,Adventure,Drama            8.9
# 582013       \N            148      Action,Adventure,Sci-Fi            8.8
# 940296       \N            135             Action,Drama,War            8.8
# 89544        \N            178       Action,Adventure,Drama            8.8
# 445593       \N            153                        Drama            8.7
# 112867       \N            179       Action,Adventure,Drama            8.7
# 990094       \N            132        Comedy,Drama,Thriller            8.6
# 183922       \N            130                  Crime,Drama            8.6
# 149309       \N            125   Adventure,Animation,Family            8.6
# 1063691      \N            160      Biography,Drama,History            8.6
# 387558       \N            169       Adventure,Drama,Sci-Fi            8.6
# 636259       \N            112       Biography,Comedy,Drama            8.5
# 152941       \N            150        Biography,Drama,Music            8.5
# 115287       \N            155       Action,Adventure,Drama            8.5
# 752115       \N            106                  Drama,Music            8.5
# 251928       \N            130         Drama,Mystery,Sci-Fi            8.5
# 590882       \N            106  Biography,Documentary,Sport            8.5
# 221907       \N            151         Crime,Drama,Thriller            8.5
#
#          numVotes
# 752672      43813
# 246038    2288140
# 112866    1632805
# 582013    2051750
# 940296     104744
# 89544     1649550
# 445593      51610
# 112867    1476251
# 990094     530801
# 183922     696002
# 149309     644957
# 1063691     51526
# 387558    1496586
# 636259     753012
# 152941     724139
# 115287    1333117
# 752115     710559
# 251928    1181694
# 590882      63861
# 221907    1181716
